# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
driver = webdriver.Chrome('./chromedriver')

url = 'https://coronaboard.kr/'
driver.get(url)

time.sleep(3)

# %% [markdown]
# ### Beautiful soup으로 웹 크롤링하기 (생략)

# %%
page = urlopen(url)
soup = BeautifulSoup(page,'lxml')
soup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-54303c7a729b> in <module>
# ----> 1 page = urlopen(url)
#       2 soup = BeautifulSoup(page,'lxml')
#       3 soup
#
# NameError: name 'urlopen' is not defined

# %% [markdown]
# ### 01) 웹 데이터 수집하기

# %%
#confirmed_case = driver.find_element_by_class_name('confirmed number')
confirmed_case_global = driver.find_element_by_xpath('//*[@id="top"]/div[6]/div[1]/div[1]/p[1]')
print('전세계 확진자 수 : ',confirmed_case_global.text)

confirmed_case_kor = driver.find_element_by_xpath('//*[@id="top"]/div[6]/div[2]/div[1]/p[1]')
print('국내 확진자 수 : ',confirmed_case_kor.text)
# Out:
# 전세계 확진자 수 :  233,605,484
# 국내 확진자 수 :  308,725

# %% [markdown]
# ### 02) 특정 국가 데이터 확인

# %%
# 더보기 버튼 클릭
from selenium.webdriver import ActionChains
some_tag = driver.find_element_by_id('show-more')
#some_tag = driver.find_element_by_xpath('//*[@id="show-more"]')
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()
# 더보기 한 번 더 클릭
some_tag = driver.find_element_by_id('show-more')
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-17-726f3128d237> in <module>
#       7 # 더보기 한번 더 클릭
#       8 some_tag = driver.find_element_by_id('show-more')
# ----> 9 ActionChains(driver).move_to_element(some_tag).perform()
#      10 some_tag.click()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/common/action_chains.py in perform(self)
#      78         """
#      79         if self._driver.w3c:
# ---> 80             self.w3c_actions.perform()
#      81         else:
#      82             for action in self._actions:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/common/actions/action_builder.py in perform(self)
#      74             if encoded['actions']:
#      75                 enc["actions"].append(encoded)
# ---> 76         self.driver.execute(Command.W3C_ACTIONS, enc)
#      77
# ...

# %% [markdown]
# #### 추가정보 선택 -> 1.콤보박스 클릭

# %%
some_tag = driver.find_element_by_xpath('//*[@id="global-slide"]/div/div[2]/div/div/button/div/div/div')
ActionChains(driver).move_to_element(some_tag).perform()
some_tag.click()

# %% [markdown]
# #### 추가정보선택 -> 2.치료중, 위중증, 인구수

# %%
sel_menu = driver.find_element_by_xpath('//*[@id="bs-select-1-1"]')
sel_menu.click()
sel_menu = driver.find_element_by_xpath('//*[@id="bs-select-1-5"]')
sel_menu.click()

sel_menu = driver.find_element_by_xpath('//*[@id="global-slide"]/div/div[2]/div/div/button')
sel_menu.click()

# %% [markdown]
# #### 추가정보선택 -> 3.나라선택

# %%
# 미국 확진자 수 xpath : //*[@id="country-table"]/div/div/table/tbody/tr[1]/td[3]
# 인도 확진자 수 xpath : //*[@id="country-table"]/div/div/table/tbody/tr[2]/td[3]
# ...
# 프랑스 확진자수 xpath: //*[@id="country-table"]/div/div/table/tbody/tr[7]/td[3]
# 프랑스 사망자수 xpath: //*[@id="country-table"]/div/div/table/tbody/tr[7]/td[6]
frech_confirm = driver.find_element_by_xpath('//*[@id="country-table"]/div/div/table/tbody/tr[7]/td[3]')
frech_death   = driver.find_element_by_xpath('//*[@id="country-table"]/div/div/table/tbody/tr[7]/td[6]')

print('프랑스 확진자 수 : ', frech_confirm.text,'\n', '프랑스 사망자 수 : ', frech_death.text)

# tr['나라번호(ex.미국,인도,프랑스 ...)']  td['컬럼번호(ex.확진자수,치료중수,사망자수 ...)']
# Out:
# 프랑스 확진자 수 :  6,995,628
# (+1,309)
#  프랑스 사망자 수 :  116,537
# (+74)

# %% [markdown]
# ### 03) 전 세계 모든 국가의 데이터

# %% [markdown]
# ##### 국가 개수 확인

# %%
sel_country = driver.find_elements_by_xpath('//*[@id="country-table"]/div/div/table/tbody/tr/td[2]')
len(sel_country)
# Out:
# 222

# %% [markdown]
# #### 반복문으로 tr[i]에 해당하는 국가명만 출력

# %%
for one in sel_country:
    print(one.text)
# Out:
# 미국🇺🇸
# 인도🇮🇳
# 브라질🇧🇷
# 영국🇬🇧
# 러시아🇷🇺
# 터키🇹🇷
# 프랑스🇫🇷
# 이란🇮🇷
# 아르헨티나🇦🇷
# 콜롬비아🇨🇴
# 스페인🇪🇸
# 이탈리아🇮🇹
# 독일🇩🇪
# 인도네시아🇮🇩
# 멕시코🇲🇽
# 폴란드🇵🇱
# 남아프리카 공화국🇿🇦
# 필리핀🇵🇭
# 우크라이나🇺🇦
# 말레이시아🇲🇾
# 페루🇵🇪
# 네덜란드🇳🇱
# 이라크🇮🇶
# 일본🇯🇵*
# 체코🇨🇿
# 칠레🇨🇱
# 캐나다🇨🇦
# 태국🇹🇭
# 방글라데시🇧🇩
# 이스라엘🇮🇱
# 파키스탄🇵🇰
# 벨기에🇧🇪
# 루마니아🇷🇴
# 스웨덴🇸🇪
# 포르투갈🇵🇹
# 모로코🇲🇦
# 세르비아🇷🇸
# 카자흐스탄🇰🇿
# 쿠바🇨🇺
# 스위스🇨🇭
# 요르단🇯🇴
# 헝가리🇭🇺
# 네팔🇳🇵
# 베트남🇻🇳
# 오스트리아🇦🇹
# 아랍에미레이트🇦🇪
# 튀니지🇹🇳
# 그리스🇬🇷
# 레바논🇱🇧
# 조지아🇬🇪
# 과테말라🇬🇹
# 사우디아라비아🇸🇦
# 벨라루스🇧🇾
# 코스타리카🇨🇷
# 스리랑카🇱🇰
# 에콰도르🇪🇨
# 볼리비아🇧🇴
# 불가리아🇧🇬
# 아제르바이잔🇦🇿
# 파나마🇵🇦
# 미얀마🇲🇲
# 파라과이🇵🇾
# 쿠웨이트🇰🇼
# 슬로바키아🇸🇰
# 크로아티아🇭🇷
# 팔레스타인🇵🇸
# 우루과이🇺🇾
# 아일랜드🇮🇪
# 베네수엘라🇻🇪
# 온두라스🇭🇳
# 도미니카 공화국🇩🇴
# 덴마크🇩🇰
# 에티오피아🇪🇹
# 리비아🇱🇾
# 리투아니아🇱🇹
# 대한민국🇰🇷
# 오만🇴🇲
# 이집트🇪🇬
# 몽골🇲🇳
# 몰도바🇲🇩
# 슬로베니아🇸🇮
# 바레인🇧🇭
# 아르메니아🇦🇲
# 케냐🇰🇪
# 카타르🇶🇦
# 보스니아 헤르체고비나🇧🇦
# 잠비아🇿🇲
# 나이지리아🇳🇬
# 알제리🇩🇿
# 북마케도니아🇲🇰
# 노르웨이🇳🇴
# 키르기스스탄🇰🇬
# 보츠와나🇧🇼
# 우즈베키스탄🇺🇿
# 알바니아🇦🇱
# 라트비아🇱🇻
# 아프가니스탄🇦🇫
# 에스토니아🇪🇪
# 모잠비크🇲🇿
# 핀란드🇫🇮
# 몬테네그로🇲🇪
# 짐바브웨🇿🇼
# 나미비아🇳🇦
# 가나🇬🇭
# 우간다🇺🇬
# 키프로스🇨🇾
# 캄보디아🇰🇭
# 코소보🇽🇰
# 엘살바도르🇸🇻
# 호주🇦🇺
# 르완다🇷🇼
# 중국🇨🇳
# 싱가포르🇸🇬
# ...

# %% [markdown]
# #### 어제 정보 확인 -> [어제]탭 클릭이 안되어있으면 클릭하기

# %%
# [어제]탭 xpath : //*[@id="global-slide"]/div/div[2]/ul/li[1]/a
# [오늘]탭 xpath : //*[@id="global-slide"]/div/div[2]/ul/li[2]/a
if flag_today==False:
    sel_yesterday = driver.find_element_by_xpath('//*[@id="global-slide"]/div/div[2]/ul/li[2]/a')
    sel_yesterday.click()

# %% [markdown]
# #### 반복문을 통해서 모든 나라(tr[i]) 와 각 나라의 여러 정보(확진자,위중증,사망자,완치,치명(%),완치(%),발생률,인구수)(td[i]) 추출하기

# %%
all_data = []
for i in range(2, 11):
    tmp = '//*[@id="country-table"]/div/div/table/tbody/tr/td[{}]'.format(i)
    # print(tmp)
    sel_ele = driver.find_elements_by_xpath(tmp)
    
    
    column_data = []
    for one in sel_ele:
        # print(one.text)
        column_data.append(one.text)
    
    print( len(sel_ele) )
    all_data.append(column_data)
    print(column_data)
    print()
    
all_data
# Out:
# 222
# ...

# %% [markdown]
# ### 04) 전세계 모든 국가 데이터로 데이터 프레임 만들기

# %%
import pandas as pd

dict_dat = { "국가":all_data[0], 
             "확진자":all_data[1],
             "위중증":all_data[2],
             "사망자":all_data[3],
             "완치":all_data[4],
             "치명(%)":all_data[5],
             "완치(%)":all_data[6],
             "발생률":all_data[7],
             "인구수":all_data[8]
           }

dat = pd.DataFrame(dict_dat)
dat
# Out:
#            국가                     확진자                   위중증             사망자  \
# 0        미국🇺🇸  43,942,335\n(+187,382)  9,838,383\n(-23,963)  21,819\n(-275)
# 1        인도🇮🇳   33,714,241\n(+21,093)     289,782\n(-7,388)           8,944
# 2       브라질🇧🇷   21,366,395\n(+14,423)     410,502\n(-6,613)           8,318
# 3        영국🇬🇧    7,701,715\n(+37,485)   1,346,396\n(+3,904)      878\n(-38)
# 4       러시아🇷🇺    7,464,708\n(+21,559)     623,692\n(+3,339)           2,300
# ..        ...                     ...                   ...             ...
# 217   마셜 제도🇲🇭                       4                     0             N/A
# 218    바누아투🇻🇺                       4                     0             N/A
# 219     사모아🇼🇸                       3                     0             N/A
# 220  세인트헬레나🇸🇭                       2                     0             N/A
# 221  미크로네시아🇫🇲                       1                     0             N/A
#
# ...

# %% [markdown]
#  ### 05) 데이터 프레임의 데이터 전처리하기

# %% [markdown]
# #### 확진자 정보

# %%
dat.columns
# Out:
# Index(['국가', '확진자', '위중증', '사망자', '완치', '치명(%)', '완치(%)', '발생률', '인구수'], dtype='object')

# %%
dat['확진자'].str.split('\n').str[0]
# Out:
# 0      43,942,335
# 1      33,714,241
# 2      21,366,395
# 3       7,701,715
# 4       7,464,708
#           ...
# 217             4
# 218             4
# 219             3
# 220             2
# 221             1
# Name: 확진자, Length: 222, dtype: object

# %%
dat.head(10)
# Out:
#         국가                     확진자                   위중증             사망자  \
# 0     미국🇺🇸  43,942,335\n(+187,382)  9,838,383\n(-23,963)  21,819\n(-275)
# 1     인도🇮🇳   33,714,241\n(+21,093)     289,782\n(-7,388)           8,944
# 2    브라질🇧🇷   21,366,395\n(+14,423)     410,502\n(-6,613)           8,318
# 3     영국🇬🇧    7,701,715\n(+37,485)   1,346,396\n(+3,904)      878\n(-38)
# 4    러시아🇷🇺    7,464,708\n(+21,559)     623,692\n(+3,339)           2,300
# 5     터키🇹🇷    7,066,688\n(+27,188)     480,881\n(+1,822)             633
# 6    프랑스🇫🇷     6,995,628\n(+1,309)    141,600\n(-13,225)           1,609
# 7     이란🇮🇷    5,559,691\n(+11,701)    451,694\n(-10,549)    6,124\n(-85)
# 8  아르헨티나🇦🇷     5,251,940\n(+1,538)        23,383\n(-561)    1,200\n(-37)
# 9   콜롬비아🇨🇴     4,952,690\n(+1,015)        33,125\n(-690)             542
#
#                   완치                   치명(%) 완치(%)   발생률      인구수
# 0  709,119\n(+2,781)  33,394,833\n(+208,564)   1.6  76.0  133,051
# ...

# %% [markdown]
# #### '합계' 와 '일일추가 인원' 구분 : 확진자, 사망자, 완치

# %%
dat['확진자_합계'] = dat['확진자'].str.split('\n').str[0]
dat['확진자_1일'] = dat['확진자'].str.split('\n').str[1]
dat['확진자'].str.split('\n').str[1]
# Out:
# 0      (+187,382)
# 1       (+21,093)
# 2       (+14,423)
# 3       (+37,485)
# 4       (+21,559)
#           ...
# 217           NaN
# 218           NaN
# 219           NaN
# 220           NaN
# 221           NaN
# Name: 확진자, Length: 222, dtype: object

# %%
dat['사망자_합계'] = dat['사망자'].str.split('\n').str[0]
dat['사망자_1일'] = dat['사망자'].str.split('\n').str[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '사망자'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-5c9b52760ea8> in <module>
# ...

# %%
dat['완치_합계'] = dat['완치'].str.split('\n').str[0]
dat['완치_1일'] = dat['완치'].str.split('\n').str[1]

# %%
dat.head()
# Out:
#       국가                     확진자                   위중증             사망자  \
# 0   미국🇺🇸  43,942,335\n(+187,382)  9,838,383\n(-23,963)  21,819\n(-275)
# 1   인도🇮🇳   33,714,241\n(+21,093)     289,782\n(-7,388)           8,944
# 2  브라질🇧🇷   21,366,395\n(+14,423)     410,502\n(-6,613)           8,318
# 3   영국🇬🇧    7,701,715\n(+37,485)   1,346,396\n(+3,904)      878\n(-38)
# 4  러시아🇷🇺    7,464,708\n(+21,559)     623,692\n(+3,339)           2,300
#
#                   완치                   치명(%) 완치(%)   발생률      인구수      확진자_합계  \
# 0  709,119\n(+2,781)  33,394,833\n(+208,564)   1.6  76.0  133,051  43,942,335
# 1    447,699\n(+337)   32,976,760\n(+28,144)   1.3  97.8   24,431  33,714,241
# 2    594,702\n(+218)   20,361,191\n(+20,818)   2.8  95.3  100,592  21,366,395
# 3     136,208\n(+40)    6,219,111\n(+33,541)   1.8  80.7  113,959   7,701,715
# 4    205,531\n(+852)    6,635,485\n(+17,368)   2.8  88.9   51,151   7,464,708
#
#        확진자_1일  사망자_합계  사망자_1일    완치_합계     완치_1일
# ...

# %% [markdown]
# #### 데이터 정리

# %%
dat = dat.drop( ['확진자', '사망자', '완치'], axis=1 )

# %%
dat.head(10)
# Out:
#         국가                   위중증                   치명(%) 완치(%)   발생률      인구수  \
# 0     미국🇺🇸  9,838,383\n(-23,963)  33,394,833\n(+208,564)   1.6  76.0  133,051
# 1     인도🇮🇳     289,782\n(-7,388)   32,976,760\n(+28,144)   1.3  97.8   24,431
# 2    브라질🇧🇷     410,502\n(-6,613)   20,361,191\n(+20,818)   2.8  95.3  100,592
# 3     영국🇬🇧   1,346,396\n(+3,904)    6,219,111\n(+33,541)   1.8  80.7  113,959
# 4    러시아🇷🇺     623,692\n(+3,339)    6,635,485\n(+17,368)   2.8  88.9   51,151
# 5     터키🇹🇷     480,881\n(+1,822)    6,522,435\n(+25,160)   0.9  92.3   84,132
# 6    프랑스🇫🇷    141,600\n(-13,225)    6,737,491\n(+14,460)   1.7  96.3  107,278
# 7     이란🇮🇷    451,694\n(-10,549)    4,988,109\n(+22,011)   2.2  89.7   66,192
# 8  아르헨티나🇦🇷        23,383\n(-561)     5,113,603\n(+2,007)   2.2  97.4  116,245
# 9   콜롬비아🇨🇴        33,125\n(-690)     4,793,387\n(+1,672)   2.5  96.8   97,368
#
#        확진자_합계      확진자_1일  사망자_합계  사망자_1일    완치_합계     완치_1일
# ...

# %% [markdown]
# #### 데이터 전처리 : 정규표현식으로 데이터값에 있는 불필요한 문자들( 소괄호() 와 콤마, ) 삭제

# %%
dat['위중증'] = dat['위중증'].str.replace(pat=r'[,()]', repl=r'', regex=True)
dat['발생률'] = dat['발생률'].str.replace(pat=r',', repl=r'', regex=True)
dat['인구수'] = dat['인구수'].str.replace(pat=r',', repl=r'', regex=True)
                                        
dat['확진자_합계'] = dat['확진자_합계'].str.replace(pat=r'[,()]', repl=r'', regex=True)
dat['확진자_1일'] = dat['확진자_1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)

dat['사망자_합계'] = dat['사망자_합계'].str.replace(pat=r'[,()]', repl=r'', regex=True)
dat['사망자_1일'] = dat['사망자_1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)

dat['완치_합계'] = dat['완치_합계'].str.replace(pat=r'[,()]', repl=r'', regex=True)
dat['완치_1일'] = dat['완치_1일'].str.replace(pat=r'[,()]', repl=r'', regex=True)

# %%
dat.head(10)
# Out:
#         국가              위중증                   치명(%) 완치(%)   발생률     인구수  \
# 0     미국🇺🇸  9838383\n-23963  33,394,833\n(+208,564)   1.6  76.0  133051
# 1     인도🇮🇳    289782\n-7388   32,976,760\n(+28,144)   1.3  97.8   24431
# 2    브라질🇧🇷    410502\n-6613   20,361,191\n(+20,818)   2.8  95.3  100592
# 3     영국🇬🇧   1346396\n+3904    6,219,111\n(+33,541)   1.8  80.7  113959
# 4    러시아🇷🇺    623692\n+3339    6,635,485\n(+17,368)   2.8  88.9   51151
# 5     터키🇹🇷    480881\n+1822    6,522,435\n(+25,160)   0.9  92.3   84132
# 6    프랑스🇫🇷   141600\n-13225    6,737,491\n(+14,460)   1.7  96.3  107278
# 7     이란🇮🇷   451694\n-10549    4,988,109\n(+22,011)   2.2  89.7   66192
# 8  아르헨티나🇦🇷      23383\n-561     5,113,603\n(+2,007)   2.2  97.4  116245
# 9   콜롬비아🇨🇴      33125\n-690     4,793,387\n(+1,672)   2.5  96.8   97368
#
#      확진자_합계   확진자_1일 사망자_합계 사망자_1일   완치_합계  완치_1일
# 0  43942335  +187382  21819   -275  709119  +2781
# 1  33714241   +21093   8944    NaN  447699   +337
# ...

# %% [markdown]
# #### 실습) 위중증 정보도 '위중증_합계'와 '위중증_1일' 로 구분하고 기존의 위중증 정보는 삭제하기

# %%
dat['위중증_합계'] = dat['위중증'].str.split('\n').str[0]
dat['위중증_1일'] = dat['위중증'].str.split('\n').str[1]
dat = dat.drop( ['위중증'], axis=1 )

dat.head(10)
# Out:
#         국가                   치명(%) 완치(%)   발생률     인구수    확진자_합계   확진자_1일  \
# 0     미국🇺🇸  33,394,833\n(+208,564)   1.6  76.0  133051  43942335  +187382
# 1     인도🇮🇳   32,976,760\n(+28,144)   1.3  97.8   24431  33714241   +21093
# 2    브라질🇧🇷   20,361,191\n(+20,818)   2.8  95.3  100592  21366395   +14423
# 3     영국🇬🇧    6,219,111\n(+33,541)   1.8  80.7  113959   7701715   +37485
# 4    러시아🇷🇺    6,635,485\n(+17,368)   2.8  88.9   51151   7464708   +21559
# 5     터키🇹🇷    6,522,435\n(+25,160)   0.9  92.3   84132   7066688   +27188
# 6    프랑스🇫🇷    6,737,491\n(+14,460)   1.7  96.3  107278   6995628    +1309
# 7     이란🇮🇷    4,988,109\n(+22,011)   2.2  89.7   66192   5559691   +11701
# 8  아르헨티나🇦🇷     5,113,603\n(+2,007)   2.2  97.4  116245   5251940    +1538
# 9   콜롬비아🇨🇴     4,793,387\n(+1,672)   2.5  96.8   97368   4952690    +1015
#
#   사망자_합계 사망자_1일   완치_합계  완치_1일   위중증_합계  위중증_1일
# 0  21819   -275  709119  +2781  9838383  -23963
# 1   8944    NaN  447699   +337   289782   -7388
# ...

# %% [markdown]
# ### csv파일로 데이터셋 저장하기

# %%
from datetime import datetime
from datetime import date
import datetime
import os

today = datetime.date.today()
yesterday = today - datetime.timedelta(days=1)

# print(today)
# print(yesterday)
if flag_today == True:
    file_make_time = today
else:
    file_make_time = yesterday

print( file_make_time )

print( os.getcwd() )
path_dir = os.getcwd() + "/output_data/"  # window는 \\output_data\\ 이고 mac은 /output_data/이다.
path_file = path_dir + str(file_make_time)
print( path_dir,  path_file, sep="\n" )
# Out:
# 2021-09-28
# /Users/works/Documents/Jupyter
# /Users/works/Documents/Jupyter/output_data/
# /Users/works/Documents/Jupyter/output_data/2021-09-28

# %%
dat.to_csv(path_file + "_coronaboard.csv", index=False)
dat.to_excel(path_file + "_coronaboard.xlsx", index=False)
os.listdir( path_dir )
# Out:
# ['2021-09-28_coronaboard.csv',
#  '2021-09-28_coronaboard.xlsx',
#  '20210929_14_vaccine_bloomberg.xlsx',
#  '2021-09-28_corona.csv',
#  '20210929_14_vaccine_bloomberg.csv',
#  '2021-09-28_corona.xlsx']
